# %%
import os
import pandas as pd
import numpy as np
import pymc as pm

#import importlib
import functions as func

# %% [markdown]
# ## No feedback only trials

# %% [markdown]
# The scripts calculates the mean for the posterior distribution of the outcomes (correct/fails trials). Only trials with the feedback (key_pressed = True) were used.

# %%
log_folder = '/Users/natapost/Documents/ultan_files/pl/logs_to_csv'
file_names = os.listdir(log_folder)
participants = []
for f in file_names:
    if f[0] != '.' and f[0] != 'd' and f[:2] != '12' and f[:2] != 'se':
        participants.append(f[:2])

difficulty_df = pd.read_csv(log_folder + '/' + 'difficult_ams.csv', index_col = 0)
print(participants)
# Out:
# ['22', '08', '20', '21', '09', '19', '18', '16', '02', '03', '17', '01', '15', '04', '10', '11', '05', '13', '07', '06']

# %%
participant = '01'
df = pd.read_csv(log_folder + '/' + participant + '.csv')
df = func.getStageIndex(df)
df
# Out:
#      Unnamed: 0  time_stimuli_start  time_space  timestamp_stimuli_start  \
# 0             0             30.2595         NaN             1.683531e+09
# 1             1             32.5061         NaN             1.683531e+09
# 2             2             34.7921         NaN             1.683531e+09
# 3             3             36.9962         NaN             1.683531e+09
# 4             4             39.0667         NaN             1.683531e+09
# ..          ...                 ...         ...                      ...
# 835         235            560.6887         NaN             1.683536e+09
# 836         236            562.7528         NaN             1.683536e+09
# 837         237            565.1932    565.8951             1.683536e+09
# 838         238            567.4730         NaN             1.683536e+09
# 839         239            569.4922         NaN             1.683536e+09
#
#      timestamp_key_pressed      RT relevant_modality     stage  trial_n  \
# 0                      NaN     NaN               AUD  training        1
# 1                      NaN     NaN               AUD  training        2
# 2                      NaN     NaN               AUD  training        3
# 3                      NaN     NaN               AUD  training        4
# 4                      NaN     NaN               AUD  training        5
# ..                     ...     ...               ...       ...      ...
# 835                    NaN     NaN               AUD      eds2       56
# 836                    NaN     NaN               AUD      eds2       57
# 837           1.683536e+09  0.7019               AUD      eds2       58
# 838                    NaN     NaN               AUD      eds2       59
# 839                    NaN     NaN               AUD      eds2       60
#
#         go  key_pressed  correct  stage_trial
# 0     True        False        0            1
# 1    False        False        1            2
# 2    False        False        1            3
# 3     True        False        0            4
# 4    False        False        1            5
# ..     ...          ...      ...          ...
# 835  False        False        1           56
# 836   True        False        0           57
# 837   True         True        1           58
# 838  False        False        1           59
# 839  False        False        1           60
#
# [840 rows x 13 columns]

# %%
outcome_folder = 'outcomes_binomial_beta_prior_NO_feedback_trials_only'
outcome_folder_files = os.listdir(outcome_folder + '/tables')
stages = ['ids1','eds1', 'ids2', 'eds2']
title = 'NO_feedback_only'
done_files = []

for participant in participants:
    if participant != '18':
        pass
    else:
        continue
        
    print('done files:', done_files.sort())
    print('                 -----------!!!!-----------')
    print('Analysing participant', participant)
    print('log_file:', participant + '.csv')
    df = pd.read_csv(log_folder + '/' + participant + '.csv')
    df = func.getStageIndex(df)
    
    for stage in stages:
        trial_n = []
        means = []
        hdi_3_all = []
        hdi_97_all = []
        csv_file_name = participant + '_' + stage + '_bayesian_NO_feedback_only.csv'
        print(csv_file_name)
        if csv_file_name in outcome_folder_files:
            print('this stage has been already done')
            continue
        else:
            progress_df = pd.DataFrame()
            print(f'creating a new file for participant {participant} stage {stage}')

        df_stage = df[df.stage == stage]
        observed_data = []

        for index, row in df_stage.iterrows():
            if row.key_pressed == False:
                pass
            else:
                continue

            print(' ')
            print('trial', row.stage_trial)
            trial_n.append(row.stage_trial)
            observed_data.append(row.correct)
            print('observed data', observed_data)
            mean, hdi_3, hdi_97 = func.distribution_update(observed_data)
            means.append(mean)
            hdi_3_all.append(hdi_3)
            hdi_97_all.append(hdi_97)

        go_trials = df_stage[df_stage.go == True].stage_trial
        func.graph_plotting(trial_n, means, hdi_3_all, hdi_97_all, observed_data, participant, stage, go_trials, title, outcome_folder)
        progress_df['trial_n'] = trial_n
        progress_df[f'{stage}_mean'] = means
        progress_df[f'{stage}_hdi_3'] = hdi_3_all
        progress_df[f'{stage}_hdi_97'] = hdi_97_all
        #print(progress_df)
        progress_df.to_csv(outcome_folder + '/' + csv_file_name)

        #break
    done_files.append(participant)
    done_files.sort()
    print(' ')
    print('done files:', done_files)
    #break
# Out:
# done files: None
#                  -----------!!!!-----------
# Analysing participant 22
# log_file: 22.csv
# 22_ids1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 22_eds1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 22_ids2_bayesian_NO_feedback_only.csv
# this stage has been already done
# 22_eds2_bayesian_NO_feedback_only.csv
# this stage has been already done
#
# done files: ['22']
# done files: None
#                  -----------!!!!-----------
# Analysing participant 08
# log_file: 08.csv
# 08_ids1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 08_eds1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 08_ids2_bayesian_NO_feedback_only.csv
# this stage has been already done
# 08_eds2_bayesian_NO_feedback_only.csv
# this stage has been already done
#
# done files: ['08', '22']
# done files: None
#                  -----------!!!!-----------
# Analysing participant 20
# log_file: 20.csv
# 20_ids1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 20_eds1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 20_ids2_bayesian_NO_feedback_only.csv
# this stage has been already done
# 20_eds2_bayesian_NO_feedback_only.csv
# this stage has been already done
#
# done files: ['08', '20', '22']
# done files: None
#                  -----------!!!!-----------
# Analysing participant 21
# log_file: 21.csv
# 21_ids1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 21_eds1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 21_ids2_bayesian_NO_feedback_only.csv
# this stage has been already done
# 21_eds2_bayesian_NO_feedback_only.csv
# this stage has been already done
#
# done files: ['08', '20', '21', '22']
# done files: None
#                  -----------!!!!-----------
# Analysing participant 09
# log_file: 09.csv
# 09_ids1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 09_eds1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 09_ids2_bayesian_NO_feedback_only.csv
# this stage has been already done
# 09_eds2_bayesian_NO_feedback_only.csv
# this stage has been already done
#
# done files: ['08', '09', '20', '21', '22']
# done files: None
#                  -----------!!!!-----------
# Analysing participant 19
# log_file: 19.csv
# 19_ids1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 19_eds1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 19_ids2_bayesian_NO_feedback_only.csv
# this stage has been already done
# 19_eds2_bayesian_NO_feedback_only.csv
# this stage has been already done
#
# done files: ['08', '09', '19', '20', '21', '22']
# done files: None
#                  -----------!!!!-----------
# Analysing participant 16
# log_file: 16.csv
# 16_ids1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 16_eds1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 16_ids2_bayesian_NO_feedback_only.csv
# this stage has been already done
# 16_eds2_bayesian_NO_feedback_only.csv
# this stage has been already done
#
# done files: ['08', '09', '16', '19', '20', '21', '22']
# done files: None
#                  -----------!!!!-----------
# Analysing participant 02
# log_file: 02.csv
# 02_ids1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 02_eds1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 02_ids2_bayesian_NO_feedback_only.csv
# this stage has been already done
# 02_eds2_bayesian_NO_feedback_only.csv
# this stage has been already done
#
# done files: ['02', '08', '09', '16', '19', '20', '21', '22']
# done files: None
#                  -----------!!!!-----------
# Analysing participant 03
# log_file: 03.csv
# 03_ids1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 03_eds1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 03_ids2_bayesian_NO_feedback_only.csv
# this stage has been already done
# 03_eds2_bayesian_NO_feedback_only.csv
# this stage has been already done
#
# done files: ['02', '03', '08', '09', '16', '19', '20', '21', '22']
# done files: None
#                  -----------!!!!-----------
# Analysing participant 17
# log_file: 17.csv
# 17_ids1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 17_eds1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 17_ids2_bayesian_NO_feedback_only.csv
# this stage has been already done
# 17_eds2_bayesian_NO_feedback_only.csv
# this stage has been already done
#
# done files: ['02', '03', '08', '09', '16', '17', '19', '20', '21', '22']
# done files: None
#                  -----------!!!!-----------
# Analysing participant 01
# log_file: 01.csv
# 01_ids1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 01_eds1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 01_ids2_bayesian_NO_feedback_only.csv
# this stage has been already done
# 01_eds2_bayesian_NO_feedback_only.csv
# this stage has been already done
#
# done files: ['01', '02', '03', '08', '09', '16', '17', '19', '20', '21', '22']
# done files: None
#                  -----------!!!!-----------
# Analysing participant 15
# log_file: 15.csv
# 15_ids1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 15_eds1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 15_ids2_bayesian_NO_feedback_only.csv
# this stage has been already done
# 15_eds2_bayesian_NO_feedback_only.csv
# this stage has been already done
#
# done files: ['01', '02', '03', '08', '09', '15', '16', '17', '19', '20', '21', '22']
# done files: None
#                  -----------!!!!-----------
# Analysing participant 04
# log_file: 04.csv
# 04_ids1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 04_eds1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 04_ids2_bayesian_NO_feedback_only.csv
# this stage has been already done
# 04_eds2_bayesian_NO_feedback_only.csv
# this stage has been already done
#
# done files: ['01', '02', '03', '04', '08', '09', '15', '16', '17', '19', '20', '21', '22']
# done files: None
#                  -----------!!!!-----------
# Analysing participant 10
# log_file: 10.csv
# 10_ids1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 10_eds1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 10_ids2_bayesian_NO_feedback_only.csv
# this stage has been already done
# 10_eds2_bayesian_NO_feedback_only.csv
# this stage has been already done
#
# done files: ['01', '02', '03', '04', '08', '09', '10', '15', '16', '17', '19', '20', '21', '22']
# done files: None
#                  -----------!!!!-----------
# Analysing participant 11
# log_file: 11.csv
# 11_ids1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 11_eds1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 11_ids2_bayesian_NO_feedback_only.csv
# this stage has been already done
# 11_eds2_bayesian_NO_feedback_only.csv
# this stage has been already done
#
# done files: ['01', '02', '03', '04', '08', '09', '10', '11', '15', '16', '17', '19', '20', '21', '22']
# done files: None
#                  -----------!!!!-----------
# Analysing participant 05
# log_file: 05.csv
# 05_ids1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 05_eds1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 05_ids2_bayesian_NO_feedback_only.csv
# this stage has been already done
# 05_eds2_bayesian_NO_feedback_only.csv
# this stage has been already done
#
# done files: ['01', '02', '03', '04', '05', '08', '09', '10', '11', '15', '16', '17', '19', '20', '21', '22']
# done files: None
#                  -----------!!!!-----------
# Analysing participant 13
# log_file: 13.csv
# 13_ids1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 13_eds1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 13_ids2_bayesian_NO_feedback_only.csv
# this stage has been already done
# 13_eds2_bayesian_NO_feedback_only.csv
# this stage has been already done
#
# done files: ['01', '02', '03', '04', '05', '08', '09', '10', '11', '13', '15', '16', '17', '19', '20', '21', '22']
# done files: None
#                  -----------!!!!-----------
# Analysing participant 07
# log_file: 07.csv
# 07_ids1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 07_eds1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 07_ids2_bayesian_NO_feedback_only.csv
# this stage has been already done
# 07_eds2_bayesian_NO_feedback_only.csv
# this stage has been already done
#
# done files: ['01', '02', '03', '04', '05', '07', '08', '09', '10', '11', '13', '15', '16', '17', '19', '20', '21', '22']
# done files: None
#                  -----------!!!!-----------
# Analysing participant 06
# log_file: 06.csv
# 06_ids1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 06_eds1_bayesian_NO_feedback_only.csv
# this stage has been already done
# 06_ids2_bayesian_NO_feedback_only.csv
# this stage has been already done
# 06_eds2_bayesian_NO_feedback_only.csv
# this stage has been already done
#
# done files: ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '13', '15', '16', '17', '19', '20', '21', '22']
