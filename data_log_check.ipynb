# %%
#import os
import pandas as pd

# %%
path = "/Users/natapost/Documents/ultan_files/"
file = '00_experiment_part3_2023_May_05_0945.log'
file_name = path + file

# %%
with open(file_name) as f:
    lines = f.readlines()
    for line in lines:
        if "EXP" not in line:
            print(line)
# Out:
# 1.3485 	WARNING 	We strongly recommend you activate the PTB sound engine in PsychoPy prefs as the preferred audio engine. Its timing is vastly superior. Your prefs are currently set to use ['sounddevice', 'PTB', 'pyo', 'pygame'] (in that order).
#
# 2.5623 	DATA 	utcTime: 1683269100.069181
#
# 2.5721 	DATA 	   Unnamed: 0 relevant_modality  aud1  aud2  vis1  vis2
#
# 0           0               VIS   254   284    73   103
#
# 1           1               VIS   350   380    88   118
#
# 2           2               VIS   350   380    88     0
#
# 3           3               AUD   161   191     1    31
#
# 4           4               AUD   455   485   133   163
#
# 5           5               AUD   455   485   133   163
#
# 6           6               VIS   559   589    19    49
#
# 2.5722 	DATA 	stage previous
#
# 2.5723 	DATA 	trials_order
#
# 2.5735 	DATA 	relevant_modality: AUD
#
# 2.5735 	DATA 	sound_on=1, vis_on=1
#
# 2.5736 	DATA 	stimuli_setting
#
# ...
